# %% [markdown]
# <a href="https://colab.research.google.com/github/Diogoa83/Algoritmo-Naive-Bayes/blob/main/equa%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sabendo que a soma de três números (a, b e c) é igual a 54 e eles são diretamente proporcionais a 3, 5 e 7, calcule esses três números e assinale a alternativa correta.
#
# a. ![image.png](data:image/png;base64,...)
#
# b. ![image.png](data:image/png;base64,...)
#
# c. ![image.png](data:image/png;base64,...)
#
# d. ![image.png](data:image/png;base64,...)
#
# e.![image.png](data:image/png;base64,...)
